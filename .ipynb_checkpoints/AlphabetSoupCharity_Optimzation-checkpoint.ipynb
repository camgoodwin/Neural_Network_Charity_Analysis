# %%
# Import our dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis = 1)

# %%
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"].values
x = application_df.drop(["IS_SUCCESSFUL","APPLICATION_TYPE","AFFILIATION","CLASSIFICATION","USE_CASE","ORGANIZATION","SPECIAL_CONSIDERATIONS","INCOME_AMT"], 1).values

# Split the preprocessed data into a training and testing dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=28)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

number_input_features = len(x_train[0]) 
hidden_nodes_layer1 =  len(x_train[0]) * 15
hidden_nodes_layer2 = len(x_train[0]) * 25
hidden_nodes_layer3 = len(x_train[0]) * 15
hidden_nodes_layer4 = len(x_train[0]) * 30

model = tf.keras.models.Sequential()

# First hidden layer
model.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

#Fourth Hidden layer
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# Output layer
model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_25 (Dense)             (None, 30)                90
# _________________________________________________________________
# dense_26 (Dense)             (None, 50)                1550
# _________________________________________________________________
# dense_27 (Dense)             (None, 30)                1530
# _________________________________________________________________
# dense_28 (Dense)             (None, 60)                1860
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 61
# ...
# Total params: 5,091
# Trainable params: 5,091
# Non-trainable params: 0
# _________________________________________________________________

# %%
number_input_features
# Out:
# 2

# %%
# Compile the model
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = model.fit(x_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 804/804 [==============================] - 1s 746us/step - loss: 30602.8578 - accuracy: 0.4955
# Epoch 2/300
# 804/804 [==============================] - 1s 755us/step - loss: 15680.5389 - accuracy: 0.4955
# Epoch 3/300
# 804/804 [==============================] - 1s 806us/step - loss: 3941.7824 - accuracy: 0.4866
# Epoch 4/300
# 804/804 [==============================] - 1s 779us/step - loss: 2972.1157 - accuracy: 0.4879
# Epoch 5/300
# 804/804 [==============================] - 1s 802us/step - loss: 12157.1141 - accuracy: 0.5183
# Epoch 6/300
# 804/804 [==============================] - 1s 741us/step - loss: 944.9622 - accuracy: 0.4996
# Epoch 7/300
# 804/804 [==============================] - 1s 744us/step - loss: 444.8226 - accuracy: 0.5012
# Epoch 8/300
# 804/804 [==============================] - 1s 744us/step - loss: 1281.2158 - accuracy: 0.5026
# Epoch 9/300
# 804/804 [==============================] - 1s 754us/step - loss: 0.7030 - accuracy: 0.5259
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6893 - accuracy: 0.5444
# Loss: 0.6892589926719666, Accuracy: 0.5443731546401978

# %%
# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# %%
# Compile the model
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Create a callback that saves the model's weights every 5 epochs
cb_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=3,
    save_weights_only=True,
    save_freq=3050)

# Train the model
fit_model = model.fit(x_train_scaled,y_train,epochs=100,callbacks=[cb_callback])

# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(x_test_scaled,y_test,verbose=3)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 751us/step - loss: 0.6929 - accuracy: 0.5264
# Epoch 2/100
# 804/804 [==============================] - 1s 760us/step - loss: 0.6919 - accuracy: 0.5311
# Epoch 3/100
# 804/804 [==============================] - 1s 775us/step - loss: 0.6918 - accuracy: 0.5312
# Epoch 4/100
# 599/804 [=====================>........] - ETA: 0s - loss: 0.6910 - accuracy: 0.5346
# Epoch 00004: saving model to checkpoints\weights.04.hdf5
# 804/804 [==============================] - 1s 781us/step - loss: 0.6912 - accuracy: 0.5331
# Epoch 5/100
# 804/804 [==============================] - 1s 899us/step - loss: 0.6926 - accuracy: 0.5227
# Epoch 6/100
# 804/804 [==============================] - 1s 808us/step - loss: 0.6914 - accuracy: 0.5307
# Epoch 7/100
# 804/804 [==============================] - 1s 756us/step - loss: 0.6918 - accuracy: 0.5260
# Epoch 8/100
# 463/804 [================>.............] - ETA: 0s - loss: 0.6913 - accuracy: 0.5306
# ...
